# %%
from ultralytics import YOLO

# Load model YOLOv12 base
model = YOLO('yolo12m.pt')  # hoặc yolo12n.pt, yolo12m.pt, yolo12l.pt

# Huấn luyện
model.train(
    data='/kaggle/working/merged_yolo_dataset/data.yaml', 
    epochs=300,
    imgsz=640,
    batch=16,
    name='yolo12-bean-finetune',
    project='/kaggle/working/yolo12_outputs'
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 39.0M/39.0M [00:00<00:00, 49.7MB/s]
# Ultralytics 8.3.102 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...
